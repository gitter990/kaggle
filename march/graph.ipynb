# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('data/train.csv')
test=pd.read_csv('data/test.csv')

# %%
train
# Out:
#         row_id                 time  x  y direction  congestion
# 0            0  1991-04-01 00:00:00  0  0        EB          70
# 1            1  1991-04-01 00:00:00  0  0        NB          49
# 2            2  1991-04-01 00:00:00  0  0        SB          24
# 3            3  1991-04-01 00:00:00  0  1        EB          18
# 4            4  1991-04-01 00:00:00  0  1        NB          60
# 5            5  1991-04-01 00:00:00  0  1        SB          58
# 6            6  1991-04-01 00:00:00  0  1        WB          26
# 7            7  1991-04-01 00:00:00  0  2        EB          31
# 8            8  1991-04-01 00:00:00  0  2        NB          49
# 9            9  1991-04-01 00:00:00  0  2        SB          46
# 10          10  1991-04-01 00:00:00  0  2        WB          29
# 11          11  1991-04-01 00:00:00  0  3        EB          18
# 12          12  1991-04-01 00:00:00  0  3        NB          16
# 13          13  1991-04-01 00:00:00  0  3        NE          21
# ...

# %%
train[train['direction'].isin(['EB'])]['congestion'][1:50]
# Out:
# 3      18
# 7      31
# 11     18
# 17     74
# 23     44
# 27     53
# 33     41
# 39     44
# 43     65
# 51     42
# 59     39
# 65     70
# 68     26
# 72     41
# 76     24
# 82     71
# 88     61
# 92     41
# 98     16
# 104    44
# 108    45
# 116    36
# 124    33
# 130    70
# 133    31
# 137    42
# 141    24
# 147    59
# 153    49
# 157    34
# 163    15
# 169    41
# 173    44
# 181    47
# 189    33
# 195    70
# 198    36
# 202    39
# 206    24
# 212    59
# 218    34
# 222    42
# 228    15
# 234    42
# 238    50
# 246    35
# 254    33
# 260    70
# 263    29
# Name: congestion, dtype: int64

# %%
x = list(range(0,50))
y=train[train['direction'].isin(['EB'])][0:50]
plt.plot(lst,train[train['direction'].isin(['EB'])]['congestion'][0:50])

# %%
train[train['direction'].isin(['EB'])]
# Out:
#         row_id                 time  x  y direction  congestion
# 0            0  1991-04-01 00:00:00  0  0        EB          70
# 3            3  1991-04-01 00:00:00  0  1        EB          18
# 7            7  1991-04-01 00:00:00  0  2        EB          31
# 11          11  1991-04-01 00:00:00  0  3        EB          18
# 17          17  1991-04-01 00:00:00  1  0        EB          74
# 23          23  1991-04-01 00:00:00  1  1        EB          44
# 27          27  1991-04-01 00:00:00  1  2        EB          53
# 33          33  1991-04-01 00:00:00  1  3        EB          41
# 39          39  1991-04-01 00:00:00  2  0        EB          44
# 43          43  1991-04-01 00:00:00  2  1        EB          65
# 51          51  1991-04-01 00:00:00  2  2        EB          42
# 59          59  1991-04-01 00:00:00  2  3        EB          39
# 65          65  1991-04-01 00:20:00  0  0        EB          70
# 68          68  1991-04-01 00:20:00  0  1        EB          26
# ...
